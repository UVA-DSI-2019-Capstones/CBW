# %%
#Loading the required packages
import os
import pandas as pd
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from collections import OrderedDict
from collections import deque
import re

# %%
#Changing the working directory
os.chdir('E:/Capstone IATH/Code')

# %%
#Attach code for getting these urls here

# %%
#URLs for the collection pages
links = ['http://cbw.iath.virginia.edu/books_display.php?id=1319',
'http://cbw.iath.virginia.edu/books_display.php?id=1325',
'http://cbw.iath.virginia.edu/books_display.php?id=1339',
'http://cbw.iath.virginia.edu/books_display.php?id=1354',
'http://cbw.iath.virginia.edu/books_display.php?id=1374',
'http://cbw.iath.virginia.edu/books_display.php?id=1467',
'http://cbw.iath.virginia.edu/books_display.php?id=1484',
'http://cbw.iath.virginia.edu/books_display.php?id=1486',
'http://cbw.iath.virginia.edu/books_display.php?id=1511',
'http://cbw.iath.virginia.edu/books_display.php?id=1512',
'http://cbw.iath.virginia.edu/books_display.php?id=1534',
'http://cbw.iath.virginia.edu/books_display.php?id=1548',
'http://cbw.iath.virginia.edu/books_display.php?id=1549',
'http://cbw.iath.virginia.edu/books_display.php?id=1598',
'http://cbw.iath.virginia.edu/books_display.php?id=1611',
'http://cbw.iath.virginia.edu/books_display.php?id=1632',
'http://cbw.iath.virginia.edu/books_display.php?id=1650',
'http://cbw.iath.virginia.edu/books_display.php?id=1745',
'http://cbw.iath.virginia.edu/books_display.php?id=1803',
'http://cbw.iath.virginia.edu/books_display.php?id=1864',
'http://cbw.iath.virginia.edu/books_display.php?id=1894',
'http://cbw.iath.virginia.edu/books_display.php?id=1968',
'http://cbw.iath.virginia.edu/books_display.php?id=1970',
'http://cbw.iath.virginia.edu/books_display.php?id=2006',
'http://cbw.iath.virginia.edu/books_display.php?id=2024',
'http://cbw.iath.virginia.edu/books_display.php?id=2058',
'http://cbw.iath.virginia.edu/books_display.php?id=2077',
'http://cbw.iath.virginia.edu/books_display.php?id=2086',
'http://cbw.iath.virginia.edu/books_display.php?id=2136',
'http://cbw.iath.virginia.edu/books_display.php?id=2137',
'http://cbw.iath.virginia.edu/books_display.php?id=2141',
'http://cbw.iath.virginia.edu/books_display.php?id=2161',
'http://cbw.iath.virginia.edu/books_display.php?id=2212',
'http://cbw.iath.virginia.edu/books_display.php?id=2236',
'http://cbw.iath.virginia.edu/books_display.php?id=2243',
'http://cbw.iath.virginia.edu/books_display.php?id=2269',
'http://cbw.iath.virginia.edu/books_display.php?id=2395',
'http://cbw.iath.virginia.edu/books_display.php?id=2439',
'http://cbw.iath.virginia.edu/books_display.php?id=2446']

# %%
#Collecting the urls of biographies from the collection urls using selenium
allurls = []
for link in links:
    browser = webdriver.Chrome()
    browser.get(link)
    buttons = browser.find_elements_by_xpath('//button[text()="Text"]')
    for button in buttons:
        button.click()
    urls = []
    for handle in browser.window_handles:
        browser.switch_to.window(handle)
        urls.append(browser.current_url)
        browser.close()
    urls = deque(urls)
    urls.popleft()
    allurls.extend(urls)

# %%
#List of urls of the biographies
allurls
# Out:
# ['http://cbw.iath.virginia.edu/exist/cbw/basic/a001/bio70',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a001/bio20',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a001/bio04',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a007/bio13',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a007/bio12',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a020/bio10',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a020/bio09',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a020/bio07',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a020/bio06',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a020/bio05',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a020/bio04',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a020/bio03',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a020/bio02',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a020/bio01',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a034/bio12',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a034/bio11',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a034/bio10',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a034/bio09',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a034/bio08',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a034/bio07',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a034/bio06',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a034/bio05',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a034/bio04',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a034/bio03',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a034/bio02',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a034/bio01',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a052A/bio18',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a143/bio12',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a143/bio11',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a143/bio10',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a143/bio08',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a143/bio07',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a143/bio06',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a143/bio05',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a143/bio04',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a143/bio03',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a143/bio02',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a143/bio01',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a160/bio04',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a160/bio03',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a160/bio02',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a160/bio01',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a162/bio09',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a162/bio08',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a162/bio07',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a162/bio06',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a162/bio05',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a162/bio04',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a162/bio03',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a162/bio02',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a162/bio01',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a185/bio11',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a185/bio10',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a185/bio09',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a185/bio08',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a185/bio07',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a185/bio06',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a185/bio05',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a185/bio04',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a185/bio03',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a185/bio02',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a185/bio01',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a186/bio26',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a186/bio25',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a186/bio24',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a186/bio23',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a186/bio22',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a186/bio21',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a186/bio20',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a186/bio19',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a186/bio18',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a186/bio17',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a186/bio16',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a186/bio15',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a186/bio14',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a186/bio13',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a186/bio12',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a186/bio11',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a186/bio10',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a186/bio09',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a186/bio08',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a186/bio07',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a186/bio06',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a186/bio05',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a186/bio04',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a186/bio03',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a186/bio02',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a186/bio01',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a207/bio12',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a207/bio11',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a207/bio10',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a207/bio09',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a207/bio08',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a207/bio07',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a207/bio06',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a207/bio05',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a207/bio04',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a207/bio03',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a207/bio02',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a207/bio01',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a221/bio17',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a221/bio16',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a221/bio15',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a221/bio14',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a221/bio13',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a221/bio12',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a221/bio11',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a221/bio09',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a221/bio08',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a221/bio07',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a221/bio05',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a221/bio04',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a221/bio02',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a221/bio01',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a221A/bio07',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a221A/bio06',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a221A/bio05',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a221A/bio04',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a221A/bio03',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a221A/bio02',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a221A/bio01',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a270/bio11',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a270/bio10',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a270/bio09',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a270/bio08',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a270/bio07',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a270/bio06',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a270/bio05',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a270/bio04',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a270/bio03',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a270/bio02',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a270/bio01',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a282/bio23',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a282/bio22',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a282/bio21',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a282/bio20',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a282/bio19',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a282/bio18',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a282/bio17',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a282/bio16',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a282/bio15',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a282/bio14',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a282/bio13',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a282/bio12',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a282/bio10',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a282/bio09',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a282/bio08',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a282/bio07',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a282/bio06',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a282/bio05',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a282/bio04',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a282/bio03',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a282/bio02',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a282/bio01',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a302A/bio10',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a302A/bio09',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a302A/bio08',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a302A/bio07',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a302A/bio06',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a302A/bio05',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a302A/bio04',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a302A/bio03',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a302A/bio02',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a302A/bio01',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a319/bio10',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a319/bio09',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a319/bio08',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a319/bio06',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a319/bio04',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a319/bio03',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a319/bio02',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a319/bio01',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a411/bio23',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a468/bio11',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a468/bio10',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a468/bio09',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a468/bio08',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a527/bio12',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a527/bio11',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a527/bio09',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a527/bio08',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a527/bio07',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a527/bio04',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a527/bio03',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a527/bio02',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a527/bio01',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a557/bio23',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a557/bio21',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a557/bio20',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a557/bio19',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a557/bio18',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a557/bio17',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a557/bio16',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a557/bio15',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a557/bio14',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a557/bio13',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a557/bio12',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a557/bio11',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a557/bio10',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a557/bio09',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a557/bio08',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a557/bio07',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a557/bio06',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a557/bio05',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a557/bio04',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a557/bio03',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a557/bio02',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a557/bio01',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a628/bio25',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a628/bio22',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a630/bio05',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a664/bio12',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a664/bio11',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a664/bio09',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a664/bio07',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a664/bio06',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a664/bio05',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a664/bio03',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a664/bio02',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a664/bio01',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a681/bio10',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a681/bio09',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a681/bio08',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a681/bio07',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a681/bio06',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a681/bio05',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a681/bio04',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a681/bio03',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a681/bio01',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a712/bio10',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a712/bio09',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a712/bio07',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a712/bio05',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a712/bio04',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a712/bio03',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a712/bio02',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a712/bio01',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a730/bio08',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a730/bio07',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a730/bio06',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a730/bio05',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a730/bio04',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a730/bio03',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a730/bio02',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a730/bio01',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a739/bio03',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a739/bio02',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a739/bio01',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a788/bio12',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a788/bio11',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a788/bio10',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a788/bio09',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a788/bio08',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a788/bio07',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a788/bio06',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a788/bio05',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a788/bio04',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a788/bio03',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a788/bio02',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a788/bio01',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a789/bio18',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a789/bio08',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a789/bio07',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a789/bio06',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a789/bio05',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a789/bio04',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a789/bio03',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a789/bio02',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a789/bio01',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a793/bio10',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a793/bio09',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a793/bio08',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a793/bio07',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a793/bio06',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a793/bio05',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a793/bio04',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a793/bio03',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a793/bio02',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a793/bio01',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a813/bio07',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a863/bio14',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a887/bio15',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a894/bio09',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a894/bio08',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a894/bio07',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a894/bio05',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a894/bio04',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a894/bio03',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a894/bio02',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a920/bio06',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a920/bio02',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a920/bio01',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/p067A/bio18',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/p091C/bio19',
#  'http://cbw.iath.virginia.edu/exist/cbw/basic/a095A/bio05']

# %%
# Open File
result = open("listofurls.csv",'w')

# Write data to file
for url in allurls:
    result.write(url + "\n")
result.close()

# %%
#Creating an empty dataframe for getting the text of all the biographies
data = pd.DataFrame()

# %%
#Getting the content
for url in allurls:
    html = requests.get(url)
    soup = BeautifulSoup(html.text,'lxml')
    pno = soup.find_all(class_ = 'PNum')
    pt = soup.find_all(class_ = 'text')
    parano = [p.text for p in pno]
    text = [t.text for t in pt]
    col = [('ParagraphNo', parano), ('ParagraphText', text)]
    df = pd.DataFrame.from_dict(OrderedDict(col))
    df['CollectionID'] = url.split('/')[-2]
    df['BiographyID'] = url.split('/')[-1]
    data = data.append(df)

# %%
#Reset index for the dataframe
data.reset_index(drop=True, inplace=True)

# %%
#Remove the paragraph number from the text column using the following function
def removepno(text):
    pos = 0
    for i,x in enumerate(text):
        if x.isalpha():        
            pos = i                  
            break
    return text[pos:]

# %%
data['ParagraphText'] = data['ParagraphText'].apply(removepno)

# %%
#Cleaning the text column to remove duplicate spaces, newline characters tab characters, leading and trailing spaces
text = data['ParagraphText']
text = [t.replace("\n","").strip() for t in text]
text = [t.replace("\t","") for t in text]
text = [re.sub(' +', ' ', t) for t in text]
data['ParagraphText'] = text

# %%
#Writing to a csv file
data.to_csv("textdatafromweb.csv", index = False)
