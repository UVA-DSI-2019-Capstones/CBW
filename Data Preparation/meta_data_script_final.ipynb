# %%
import os
import xml.etree.ElementTree as ET
import re
import pandas as pd

def xml_to_dataframe(xml_file_path, collection_id):
    
    data = open(xml_file_path,"rb")
    tree = ET.parse (data)

    #a007_data = open('a007.csv', 'w')

    root=tree.getroot()
    #import csv
    #csvwriter = csv.writer(a007_data)
    a007_head = []

    member = root.find('div2')
    
    if(member == None):
        member = root.find('text').find('body').find('div1').find('div2')
    para_text = {}
    
   #if len(member.getchildren())==1:
        #para_text['Para_no:'+each.get('n')] = each.text
        #member.getchildren().get('n').text

    #print(member)
    for each in member:
        #print(each)
        if(each.tag == 'p'):
            para_text['Para_no:'+each.get('n')] = each.text


    
    d1=pd.DataFrame.from_dict(data = para_text, orient = 'index')
    d1

    member = root.find('teiHeader')


    book_title = member.getchildren()[0].getchildren()[0].getchildren()[0].text
    author = member.getchildren()[0].getchildren()[0].getchildren()[1].text
    
    if len(member.getchildren()[0].getchildren()[1].getchildren())==2:
        publisher = member.getchildren()[0].getchildren()[1].getchildren()[0].text
        publisher2=member.getchildren()[0].getchildren()[1].getchildren()[1].text
    else:
        publisher = member.getchildren()[0].getchildren()[1].getchildren()[0].text
        publisher2="None"
    
    bio_id=root.getchildren()[1].get('id')
    print(bio_id)
    if bio_id == None:
        print('entering loop')
        bio_id = root.find('text').find('body').find('div1').find('div2').get('id')
        print(bio_id)
    
    text_type=root.getchildren()[1].get('type')
    
    if Text_type.isnull()
    print(Text_type)
    
    bio_title=root.getchildren()[1].getchildren()[0].getchildren()[0].text.strip()
    
    if bio_title == "":
        bio_title = root.find('text').find('body').find('div1').find('div2').find('head').find('hi').text.strip()
        
    
    
    d = {'Book_title':book_title, 'Collection_Id': collection_id, 'Author':author,
         'Publisher1':publisher, 'Publisher2':publisher2, 'Biography_id':bio_id,
         'Text_type':text_type, 'Biography_title':bio_title}
   # print(d)


    df = pd.DataFrame(d, index=[0])
    df

    d1 = pd.DataFrame(d1)
    #d1.reset_index(drop= True)
    df.head()

    #Repeating the dataframe for nubmer of paragraphs
    df_1 = pd.concat([df]*d1.shape[0],ignore_index = True)

    #Cbind here
    d1['Para_no'] = d1.index
    combined_df = pd.concat([d1.reset_index(drop = True),df_1], axis = 1)





    return(combined_df)


#xml_file_path="/Users/user/Documents/capstone/data/books/a007/bio12/a007bio12.xml"
#xml_to_dataframe(xml_file_path)
# Out:
#   File "<ipython-input-249-ae26b4f7abcc>", line 61
#     if Text_type.isnull()
#                          ^
# SyntaxError: invalid syntax

# %%
path_overall = '/Users/user/Documents/capstone/data/books'
#Initializing an empty data frame
xml_df_all = pd.DataFrame()

### Looping through each of the collective biography
for a_files in os.listdir(path_overall):
    #print(a_files)
    if(os.path.isdir(path_overall+"//"+a_files)):
        #print("entering")
        ### Looping through each of the individual biography
        for bio_files in os.listdir(path_overall+"//"+a_files):
            
            #print(os.path.isdir(path_overall+"\\"+a_files))
            if(os.path.isdir(path_overall+"//"+a_files+"//"+bio_files)):
                
                files = os.listdir(path_overall+"//"+a_files+"//"+bio_files)
                #print(bio_files)
                #print(files)
                xml_files = [each_file for each_file in files if ".xml" in each_file and ".bess" not in each_file]
                ### Looping through each of the valid file in an individual biography
                for each_xml_file in xml_files:
                    #print(each_xml_file)
                    xml_file_path  = path_overall+"//"+a_files+"//"+bio_files+"//"+each_xml_file
                    collection_id = a_files[:4]
                    print(collection_id)
                    xml_df_current = xml_to_dataframe(xml_file_path, collection_id)
                    xml_df_all = pd.concat([xml_df_all,xml_df_current],axis = 0)
                    xml_df_all.reset_index(drop = True, inplace= True)
# Out:
# a007
# bio12
# a007
# bio13
# a001
# bio04
# a001
# bio20
# a001
# bio70
# a624
# bio26
# a411
# bio23
# a630
# None
# entering loop
# bio05
# a863
# None
# entering loop
# bio11
# a863
# bio14

# %%
pd.DataFrame(xml_df_all).query('Text_type=np.nan')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-236-6e3335c6f4b2> in <module>()
# ----> 1 pd.DataFrame(xml_df_all).query('Text_type=np.nan')
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    2842         kwargs['level'] = kwargs.pop('level', 0) + 1
#    2843         kwargs['target'] = None
# -> 2844         res = self.eval(expr, **kwargs)
#    2845
#    2846         try:
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    2957             kwargs['target'] = self
#    2958         kwargs['resolvers'] = kwargs.get('resolvers', ()) + tuple(resolvers)
# -> 2959         return _eval(expr, inplace=inplace, **kwargs)
#    2960
#    2961     def select_dtypes(self, include=None, exclude=None):
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/computation/eval.py in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     289
#     290         parsed_expr = Expr(expr, engine=engine, parser=parser, env=env,
# --> 291                            truediv=truediv)
#     292
#     293         # construct the engine and evaluate the parsed expression
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expr.py in __init__(self, expr, engine, parser, env, truediv, level)
#     737         self.env.scope['truediv'] = truediv
#     738         self._visitor = _parsers[parser](self.env, self.engine, self.parser)
# --> 739         self.terms = self.parse()
#     740
#     741     @property
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expr.py in parse(self)
#     754     def parse(self):
#     755         """Parse an expression"""
# --> 756         return self._visitor.visit(self.expr)
#     757
#     758     @property
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     319         method = 'visit_' + node.__class__.__name__
#     320         visitor = getattr(self, method)
# --> 321         return visitor(node, **kwargs)
#     322
#     323     def visit_Module(self, node, **kwargs):
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expr.py in visit_Module(self, node, **kwargs)
#     325             raise SyntaxError('only a single expression is allowed')
#     326         expr = node.body[0]
# --> 327         return self.visit(expr, **kwargs)
#     328
#     329     def visit_Expr(self, node, **kwargs):
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     319         method = 'visit_' + node.__class__.__name__
#     320         visitor = getattr(self, method)
# --> 321         return visitor(node, **kwargs)
#     322
#     323     def visit_Module(self, node, **kwargs):
#
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/computation/expr.py in visit_Assign(self, node, **kwargs)
#     506                               'single name')
#     507         if self.env.target is None:
# --> 508             raise ValueError('cannot assign without a target object')
#     509
#     510         try:
#
# ValueError: cannot assign without a target object

# %%
df =pd.DataFrame(xml_df_all)

# %%
df.loc[df.Text_type.isnull(), :]
# Out:
#                                                      0     Para_no  \
# 0     FRANCES MILTON, so well known in English lite...   Para_no:1
# 1     That Mrs. Trollope's prejudices sometimes pre...   Para_no:2
# 2     Mrs. Trollope's animadversions are obsolete o...   Para_no:3
# 3     "This lady," she says, "shall be the wife of ...   Para_no:4
# 4     "She rises, and her first hour is spent in th...   Para_no:5
# 5    A harmless day, after all! No doubt such days ...   Para_no:6
# 6     After an unsuccessful attempt to make a home ...   Para_no:7
# 7    Three years later she produced her "Paris and ...   Para_no:8
# 8     Mrs. Trollope records as an historical and no...   Para_no:9
# 9     Mrs. Trollope preserves two other words, whic...  Para_no:10
# 10    That Mrs. Trollope had no sympathy with the R...  Para_no:11
# 11    In truth, she is seldom happy in her literary...  Para_no:12
# 12    But from literature let us turn to society, i...  Para_no:13
# 13    To one of the worst enemies of the old-fashio...  Para_no:14
# 14    In 1835 the Parisians sometimes fell to blows...  Para_no:15
William Henry Davenport Adams  Sonnenschein     Dutton        bio12
# 23   William Henry Davenport Adams  Sonnenschein     Dutton        bio12
# 24   William Henry Davenport Adams  Sonnenschein     Dutton        bio12
# 25   William Henry Davenport Adams  Sonnenschein     Dutton        bio12
# 26   William Henry Davenport Adams  Sonnenschein     Dutton        bio12
# 27   William Henry Davenport Adams  Sonnenschein     Dutton        bio12
# 28   William Henry Davenport Adams  Sonnenschein     Dutton        bio12
# 29   William Henry Davenport Adams  Sonnenschein     Dutton        bio12
# ..                             ...           ...        ...          ...
# 251              Clara H. Whitmore      Putnam's       None        bio14
# 252              Clara H. Whitmore      Putnam's       None        bio14
# 253              Clara H. Whitmore      Putnam's       None        bio14
# 254              Clara H. Whitmore      Putnam's       None        bio14
# 255              Clara H. Whitmore      Putnam's       None        bio14
# 256              Clara H. Whitmore      Putnam's       None        bio14
# 257              Clara H. Whitmore      Putnam's       None        bio14
# 258              Clara H. Whitmore      Putnam's       None        bio14
# 259              Clara H. Whitmore      Putnam's       None        bio14
# 260              Clara H. Whitmore      Putnam's       None        bio14
# 261              Clara H. Whitmore      Putnam's       None        bio14
# 262              Clara H. Whitmore      Putnam's       None        bio14
# 263              Clara H. Whitmore      Putnam's       None        bio14
# 264              Clara H. Whitmore      Putnam's       None        bio14
# 265              Clara H. Whitmore      Putnam's       None        bio14
# 266              Clara H. Whitmore      Putnam's       None        bio14
# 267              Clara H. Whitmore      Putnam's       None        bio14
# 268              Clara H. Whitmore      Putnam's       None        bio14
# 269              Clara H. Whitmore      Putnam's       None        bio14
# 270              Clara H. Whitmore      Putnam's       None        bio14
# 271              Clara H. Whitmore      Putnam's       None        bio14
# 272              Clara H. Whitmore      Putnam's       None        bio14
# 273              Clara H. Whitmore      Putnam's       None        bio14
# 274              Clara H. Whitmore      Putnam's       None        bio14
# 275              Clara H. Whitmore      Putnam's       None        bio14
# 276              Clara H. Whitmore      Putnam's       None        bio14
# 277              Clara H. Whitmore      Putnam's       None        bio14
# 278              Clara H. Whitmore      Putnam's       None        bio14
# 279              Clara H. Whitmore      Putnam's       None        bio14
# 280              Clara H. Whitmore      Putnam's       None        bio14
#
#     Text_type                                 Biography_title
# 0        None                                   MRS. TROLLOPE
# 1        None                                   MRS. TROLLOPE
# 2        None                                   MRS. TROLLOPE
# 3        None                                   MRS. TROLLOPE
# 4        None                                   MRS. TROLLOPE
# 5        None                                   MRS. TROLLOPE
# 6        None                                   MRS. TROLLOPE
# 7        None                                   MRS. TROLLOPE
# 8        None                                   MRS. TROLLOPE
# 9        None                                   MRS. TROLLOPE
# 10       None                                   MRS. TROLLOPE
# 11       None                                   MRS. TROLLOPE
# 12       None                                   MRS. TROLLOPE
# 13       None                                   MRS. TROLLOPE
# 14       None                                   MRS. TROLLOPE
# 15       None                                   MRS. TROLLOPE
# 16       None                                   MRS. TROLLOPE
# 17       None                                   MRS. TROLLOPE
# 18       None                                   MRS. TROLLOPE
# 19       None                                   MRS. TROLLOPE
# 20       None                                   MRS. TROLLOPE
# 21       None                                   MRS. TROLLOPE
# 22       None                                   MRS. TROLLOPE
# 23       None                                   MRS. TROLLOPE
# 24       None                                   MRS. TROLLOPE
# 25       None                                   MRS. TROLLOPE
# 26       None                                   MRS. TROLLOPE
# 27       None                                   MRS. TROLLOPE
# 28       None                                   MRS. TROLLOPE
# 29       None                                   MRS. TROLLOPE
# ..        ...                                             ...
# 251      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 252      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 253      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 254      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 255      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 256      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 257      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 258      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 259      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 260      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 261      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 262      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 263      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 264      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 265      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 266      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 267      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 268      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 269      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 270      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 271      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 272      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 273      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 274      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 275      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 276      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 277      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 278      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 279      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
# 280      None  Julia Pardoe. Mrs. Trollope. Harriet Martineau
#
# [281 rows x 10 columns]

# %%
pd.DataFrame(xml_df_all)[140:147]
# Out:
#                                                      0     Para_no  \
# 140  Moreover, such writers as Mrs. Trollope, who m...  Para_no:15
# 141  Whether one agrees with Mrs. Trollope's opinio...  Para_no:16
# 142  The revivalist characteristics are the same in...  Para_no:17
# 143  The appearance of a female lecturer, who discu...  Para_no:18
# 144  In short, Mrs. Trollope' s two volumes on the ...  Para_no:19
# 145   THERE was excitement and expectation among th...   Para_no:1
# 146   The play selected for the first appearance of...   Para_no:2
#
#                                             Book_title Collection_Id  \
# 140  The Mothers of Great Men and Women, and Some W...          a411
# 141  The Mothers of Great Men and Women, and Some W...          a411
# 142  The Mothers of Great Men and Women, and Some W...          a411
# 143  The Mothers of Great Men and Women, and Some W...          a411
# 144  The Mothers of Great Men and Women, and Some W...          a411
# 145  Eminent Women of the Age: Being Narratives of ...          a630
# 146  Eminent Women of the Age: Being Narratives of ...          a630
#
#                     Author         Publisher1         Publisher2 Biography_id  \
# 140  Laura Carter Holloway  Funk and Wagnalls               None        bio23
# 141  Laura Carter Holloway  Funk and Wagnalls               None        bio23
# 142  Laura Carter Holloway  Funk and Wagnalls               None        bio23
# 143  Laura Carter Holloway  Funk and Wagnalls               None        bio23
# 144  Laura Carter Holloway  Funk and Wagnalls               None        bio23
# 145           James Parton              Betts  Gibbs and Nichols        bio05
# 146           James Parton              Betts  Gibbs and Nichols        bio05
#
#     Text_type                                  Biography_title
# 140   chapter  FRANCES TROLLOPE THE MOTHER OF ANTHONY TROLLOPE
# 141   chapter  FRANCES TROLLOPE THE MOTHER OF ANTHONY TROLLOPE
# 142   chapter  FRANCES TROLLOPE THE MOTHER OF ANTHONY TROLLOPE
# 143   chapter  FRANCES TROLLOPE THE MOTHER OF ANTHONY TROLLOPE
# 144   chapter  FRANCES TROLLOPE THE MOTHER OF ANTHONY TROLLOPE
# 145      None                         MRS. FRANCES ANNE KEMBLE
# 146      None                         MRS. FRANCES ANNE KEMBLE

# %%
df.Text_type.dtype
# Out:
# dtype('O')

# %%
pd.DataFrame(xml_df_all).Text_type==None
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 251    False
# 252    False
# 253    False
# 254    False
# 255    False
# 256    False
# 257    False
# 258    False
# 259    False
# 260    False
# 261    False
# 262    False
# 263    False
# 264    False
# 265    False
# 266    False
# 267    False
# 268    False
# 269    False
# 270    False
# 271    False
# 272    False
# 273    False
# 274    False
# 275    False
# 276    False
# 277    False
# 278    False
# 279    False
# 280    False
# Name: Text_type, Length: 281, dtype: bool

# %%
data = open(xml_file_path,"rb")
tree = ET.parse (data)

#a007_data = open('a007.csv', 'w')

root=tree.getroot()
root.getchildren()
# Out:
# [<Element 'teiHeader' at 0x11341a4f8>, <Element 'text' at 0x11341a8b8>]

# %%
data = open("/Users/user/Documents/capstone/data/books/a630/bio05/a630.bio05.xml","rb")
tree = ET.parse (data)
root=tree.getroot()
root.find('text').find('body').find('div1').find('div2').get('id')
#root.getchildren()[1].get('id')
#publicationStmt
# Out:
# 'bio05'

# %%
root.find('text').find('body').find('div1').find('div2').find('head').find('hi').text.strip()
# Out:
# 'MRS. FRANCES ANNE KEMBLE'

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
