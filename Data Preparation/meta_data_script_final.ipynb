# %%
import os
import xml.etree.ElementTree as ET
import re


def xml_to_dataframe(xml_file_path):
    
    data = open(xml_file_path,"rb")
    tree = ET.parse (data)

    #a007_data = open('a007.csv', 'w')

    root=tree.getroot()
    #import csv
    #csvwriter = csv.writer(a007_data)
    a007_head = []

    member = root.find('div2')
    para_text = {}


    for each in member:
        if(each.tag == 'p'):
            para_text['Para_no:'+each.get('n')] = each.text


    import pandas as pd
    d1=pd.DataFrame.from_dict(data = para_text, orient = 'index')
    d1

    member = root.find('teiHeader')


    book_title = member.getchildren()[0].getchildren()[0].getchildren()[0].text
    author = member.getchildren()[0].getchildren()[0].getchildren()[1].text
    publisher = member.getchildren()[0].getchildren()[1].getchildren()[0].text
    publisher2=member.getchildren()[0].getchildren()[1].getchildren()[1].text
    bio_id=root.getchildren()[1].get('id')
    text_type=root.getchildren()[1].get('type')
    bio_title=root.getchildren()[1].getchildren()[0].getchildren()[0].text.strip()

    d = {'Book_title':book_title,'Author':author, 'Publisher1':publisher, 'Publisher2':publisher2, 'Biography_id':bio_id, 'Text_type':text_type, 'Biography_title':bio_title}


    df = pd.DataFrame(d, index=[0])
    df

    d1 = pd.DataFrame(d1)
    #d1.reset_index(drop= True)
    df.head()

    #Repeating the dataframe for nubmer of paragraphs
    df_1 = pd.concat([df]*d1.shape[0],ignore_index = True)

    #Cbind here
    combined_df = pd.concat([d1.reset_index(drop = True),df_1], axis = 1)




    return(combined_df)


#xml_file_path="/Users/user/Documents/capstone/data/books/a007/bio12/a007bio12.xml"
#xml_to_dataframe(xml_file_path)
# Out:
#                                                     0  \
# 0    FRANCES MILTON, so well known in English lite...
# 1    That Mrs. Trollope's prejudices sometimes pre...
# 2    Mrs. Trollope's animadversions are obsolete o...
# 3    "This lady," she says, "shall be the wife of ...
# 4    "She rises, and her first hour is spent in th...
# 5   A harmless day, after all! No doubt such days ...
# 6    After an unsuccessful attempt to make a home ...
# 7   Three years later she produced her "Paris and ...
# 8    Mrs. Trollope records as an historical and no...
# 9    Mrs. Trollope preserves two other words, whic...
# 10   That Mrs. Trollope had no sympathy with the R...
# 11   In truth, she is seldom happy in her literary...
# 12   But from literature let us turn to society, i...
# 13   To one of the worst enemies of the old-fashio...
# 14   In 1835 the Parisians sometimes fell to blows...
# 15   Of the numerous suicides which half a century...
# 16   But instead, the elder of the two began by de...
# 17   The landlord was furious. He did not believe ...
# 18  The following day, impelled half by a wish to ...
# 19   On a small table in the room lay several pape...
# 20  It is a pity that their yearning for posthumou...
# 21   We have hinted that Mrs. Trollope's strength ...
# 22  When she diverts her thoughts, she says, from ...
# 6    chapter   MRS. TROLLOPE
# 7    chapter   MRS. TROLLOPE
# 8    chapter   MRS. TROLLOPE
# 9    chapter   MRS. TROLLOPE
# 10   chapter   MRS. TROLLOPE
# 11   chapter   MRS. TROLLOPE
# 12   chapter   MRS. TROLLOPE
# 13   chapter   MRS. TROLLOPE
# 14   chapter   MRS. TROLLOPE
# 15   chapter   MRS. TROLLOPE
# 16   chapter   MRS. TROLLOPE
# 17   chapter   MRS. TROLLOPE
# 18   chapter   MRS. TROLLOPE
# 19   chapter   MRS. TROLLOPE
# 20   chapter   MRS. TROLLOPE
# 21   chapter   MRS. TROLLOPE
# 22   chapter   MRS. TROLLOPE
# 23   chapter   MRS. TROLLOPE
# 24   chapter   MRS. TROLLOPE
# 25   chapter   MRS. TROLLOPE
# 26   chapter   MRS. TROLLOPE
# 27   chapter   MRS. TROLLOPE
# 28   chapter   MRS. TROLLOPE
# 29   chapter   MRS. TROLLOPE

# %%
path_overall = '/Users/user/Documents/capstone/data/books'
#Initializing an empty data frame
xml_df_all = pd.DataFrame()

### Looping through each of the collective biography
for a_files in os.listdir(path_overall):
    #print(a_files)
    if(os.path.isdir(path_overall+"//"+a_files)):
        #print("entering")
        ### Looping through each of the individual biography
        for bio_files in os.listdir(path_overall+"//"+a_files):
            
            #print(os.path.isdir(path_overall+"\\"+a_files))
            if(os.path.isdir(path_overall+"//"+a_files+"//"+bio_files)):
                
                files = os.listdir(path_overall+"//"+a_files+"//"+bio_files)
                #print(bio_files)
                #print(files)
                xml_files = [each_file for each_file in files if ".xml" in each_file and ".bess.xml" not in each_file]
                ### Looping through each of the valid file in an individual biography
                for each_xml_file in xml_files:
                    print(each_xml_file)
                    xml_file_path  = path_overall+"//"+a_files+"//"+bio_files+"//"+each_xml_file
                    xml_df_current = xml_to_dataframe(xml_file_path)
                    xml_df_all = pd.concat([xml_df_all,xml_df_current],axis = 0)
                    xml_df_all.reset_index(drop = True, inplace= True)
# Out:
# template.bess.new.xml
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-6736468e5b31> in <module>()
#      22                     print(each_xml_file)
#      23                     xml_file_path  = path_overall+"//"+a_files+"//"+bio_files+"//"+each_xml_file
# ---> 24                     xml_df_current = xml_to_dataframe(xml_file_path)
#      25                     xml_df_all = pd.concat([xml_df_all,xml_df_current],axis = 0)
#      26                     xml_df_all.reset_index(drop = True, inplace= True)
#
# <ipython-input-4-5f89904a42c2> in xml_to_dataframe(xml_file_path)
#      20
#      21
# ---> 22     for each in member:
#      23         if(each.tag == 'p'):
#      24             para_text['Para_no:'+each.get('n')] = each.text
#
# TypeError: 'NoneType' object is not iterable
